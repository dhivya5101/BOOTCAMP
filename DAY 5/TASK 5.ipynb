# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

X, _ = make_blobs(n_samples=300, centers=4, cluster_std=1.0, random_state=42)

optimal_k = 4
kmeans = KMeans(n_clusters=optimal_k, random_state=42, n_init=10)
kmeans.fit(X)
labels = kmeans.labels_
centroids = kmeans.cluster_centers_

cluster_data = pd.DataFrame(X, columns=['Feature 1', 'Feature 2'])
cluster_data['Cluster'] = labels

cluster_summary = cluster_data.groupby('Cluster').mean()
print("Cluster Summary:\n", cluster_summary)

plt.figure(figsize=(8, 5))
for i in range(optimal_k):
    plt.scatter(X[labels == i, 0], X[labels == i, 1], label=f'Cluster {i}')
plt.scatter(centroids[:, 0], centroids[:, 1], marker='X', s=200, c='black', label='Centroids')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('K-Means Clustering Visualization')
plt.legend()
plt.grid()
plt.show()
print("Clusters have been identified and analyzed. Refer to the summary for key characteristics.")
# Out:
# Cluster Summary:
#           Feature 1  Feature 2
# Cluster
# 0        -2.709811   8.971433
# 1        -6.832352  -6.830457
# 2         4.718205   2.041797
# 3        -8.873572   7.174583
# Clusters have been identified and analyzed. Refer to the summary for key characteristics.
